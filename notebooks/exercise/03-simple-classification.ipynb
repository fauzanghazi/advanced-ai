# %% [markdown]
# Import necassary libraries

# %% [markdown]
# Import and display the dataset

# %% [markdown]
# seperate the dataset into input and target and display the table

# %% [markdown]
# do some data pre-processing. Convert target into numeric

# %% [markdown]
# split the dataset into training and testing

# %% [markdown]
# train the model

# %% [markdown]
# test the dataset. make prediction

# %% [markdown]
# evaluate the performance
